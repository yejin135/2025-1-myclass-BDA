# %% [markdown]
# <a href="https://colab.research.google.com/github/yejin135/2025-1-myclass-BDA/blob/main/inclass/01w_A_mon_0310_BDA_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
sys.version
# Out:
# '3.11.12 (main, Apr  9 2025, 08:55:54) [GCC 11.4.0]'

# %%
import site
site.getsitepackages()
# Out:
# ['/usr/local/lib/python3.11/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/lib/python3.11/dist-packages']

# %%
import numpy as np
import pandas as pd

print(np.__version__)
print(pd.__version__)
# Out:
# 2.0.2
# 2.2.2

# %%
# !pip install koreanize-matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 66.6 MB/s eta 0:00:00
# ...

# %%
# 그림 선명하게
# %config InlineBackend.figure_format = 'retina'

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib

plt.plot([-1, 0, 1, 2])
plt.title('그래프 제목', fontweight = 'bold')
plt.xlabel('x 축')
plt.show()

# %% [markdown]
# # 시리즈 개요

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], name='first')
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# Name: first, dtype: float64

# %%
print(s.name)
print(s.index)
print(s.values)
print(s.shape)
print(s.size)
# Out:
# first
# RangeIndex(start=0, stop=6, step=1)
# [ 1.  3.  5. nan  6.  8.]
# (6,)
# 6

# %% [markdown]
# # 시리즈 인덱싱과 슬라이싱

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# Name: first, dtype: float64

# %%
s[1]
# Out:
# np.float64(3.0)

# %%
s[1:5]
# Out:
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# Name: first, dtype: float64

# %%
s[2] = 50
s
# Out:
# 0     1.0
# 1     3.0
# 2    50.0
# 3     NaN
# 4     6.0
# 5     8.0
# Name: first, dtype: float64

# %%
s.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
s.index = list('abcdef')
s
# Out:
# a     1.0
# b     3.0
# c    50.0
# d     NaN
# e     6.0
# f     8.0
# Name: first, dtype: float64

# %%
s['a']
# Out:
# np.float64(1.0)

# %%
s[0]
# Out:
# <ipython-input-17-c9c96910e542>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s[0]
# np.float64(1.0)

# %%
s[1:5]
# Out:
# b     3.0
# c    50.0
# d     NaN
# e     6.0
# Name: first, dtype: float64

# %%
s['a':'d']
# Out:
# a     1.0
# b     3.0
# c    50.0
# d     NaN
# Name: first, dtype: float64

# %%
s1 = s[1:4]
s1
# Out:
# b     3.0
# c    50.0
# d     NaN
# Name: first, dtype: float64

# %%
s1[0]
# Out:
# <ipython-input-21-bfed54b371ac>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s1[0]
# np.float64(3.0)

# %%
s.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f'], dtype='object')

# %%
s.index = np.arange(1, 7)
s
# Out:
# 1     1.0
# 2     3.0
# 3    50.0
# 4     NaN
# 5     6.0
# 6     8.0
# Name: first, dtype: float64

# %%
s[1]
# Out:
# np.float64(1.0)

# %%
s[1:4]
# Out:
# 2     3.0
# 3    50.0
# 4     NaN
# Name: first, dtype: float64

# %% [markdown]
# # 시리즈 고급 인덱싱

# %%
age = pd.Series([9, 17, 32, 45, 65, 98], index=list('abcdef'), name='age')
age
# Out:
# a     9
# b    17
# c    32
# d    45
# e    65
# f    98
# Name: age, dtype: int64

# %%
age[ [1, 3, 5] ]
# Out:
# <ipython-input-27-2da834005b2c>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   age[ [1, 3, 5] ]
# b    17
# d    45
# f    98
# Name: age, dtype: int64

# %%
age[ ['a', 'c'] ]
# Out:
# a     9
# c    32
# Name: age, dtype: int64

# %%
age['f']
# Out:
# np.int64(98)

# %%
age[ ['f'] ]
# Out:
# f    98
# Name: age, dtype: int64

# %% [markdown]
# # 불리안 인덱싱

# %%
s = pd.Series([3, 6, -3, 0, -4, 8, -7])
s
# Out:
# 0    3
# 1    6
# 2   -3
# 3    0
# 4   -4
# 5    8
# 6   -7
# dtype: int64

# %%
s > 0
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# dtype: bool

# %%
s[ s>0 ]
# Out:
# 0    3
# 1    6
# 5    8
# dtype: int64

# %%
s [s%2 == 0 ]
# Out:
# 1    6
# 3    0
# 4   -4
# 5    8
# dtype: int64

# %% [markdown]
# ## 종료
