# %% [markdown]
# <a href="https://colab.research.google.com/github/yejin135/2025-1-myclass-BDA/blob/main/inclass/13w_A_mon_0609_easy_ch10_text_mining_BTS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 13주 BTS 댓글 워드 클라우드

# %%
# !pip install koreanize-matplotlib
# Out:
# Collecting koreanize-matplotlib
#   Downloading koreanize_matplotlib-0.1.1-py3-none-any.whl.metadata (992 bytes)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from koreanize-matplotlib) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->koreanize-matplotlib) (1.17.0)
# Downloading koreanize_matplotlib-0.1.1-py3-none-any.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 55.4 MB/s eta 0:00:00
# Installing collected packages: koreanize-matplotlib
# Successfully installed koreanize-matplotlib-0.1.1

# %%
import koreanize_matplotlib

# %%
# !find / -name NanumGothic.ttf
# Out:
# /usr/local/lib/python3.11/dist-packages/koreanize_matplotlib/fonts/NanumGothic.ttf
# find: ‘/proc/70/task/70/net’: Invalid argument
# find: ‘/proc/70/net’: Invalid argument

# %%
FONT_PATH = '/usr/local/lib/python3.11/dist-packages/koreanize_matplotlib/fonts/NanumGothic.ttf'

# %%
# !pip show wordcloud
# Out:
# Name: wordcloud
# Version: 1.9.4
# Summary: A little word cloud generator
# Home-page: https://github.com/amueller/word_cloud
# Author:
# Author-email: Andreas Mueller <t3kcit+wordcloud@gmail.com>
# License: MIT License
# Location: /usr/local/lib/python3.11/dist-packages
# Requires: matplotlib, numpy, pillow
# Required-by:

# %%
# !pip show konlpy
# Out:
# WARNING: Package(s) not found: konlpy

# %%
# !pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting JPype1>=0.7.0 (from konlpy)
#   Downloading jpype1-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.11/dist-packages (from konlpy) (5.4.0)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.11/dist-packages (from konlpy) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from JPype1>=0.7.0->konlpy) (24.2)
# Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 71.0 MB/s eta 0:00:00
# Downloading jpype1-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (494 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 494.1/494.1 kB 31.5 MB/s eta 0:00:00
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.5.2 konlpy-0.6.0

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
# !git clone https://github.com/ai7dnn/data
# Out:
# Cloning into 'data'...
# remote: Enumerating objects: 50, done.
# remote: Counting objects: 100% (50/50), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 50 (delta 12), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (50/50), 5.71 MiB | 4.19 MiB/s, done.
# Resolving deltas: 100% (12/12), done.

# %%
df = pd.read_csv('data/news_comment_BTS.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   reg_time  1200 non-null   object
#  1   reply     1200 non-null   object
#  2   press     1200 non-null   object
#  3   title     1200 non-null   object
#  4   url       1200 non-null   object
# dtypes: object(5)
# memory usage: 47.0+ KB

# %%
df.sample(5)
# Out:
#                  reg_time                                              reply  \
# 1122  2020-09-01 09:07:40                             너무 자랑스럽네요\n방탄이 있어 행복해요
# 914   2020-09-01 03:05:33                                  이제야 인정해주네 그저 빛 ..
# 514   2020-09-01 08:54:57  군대 보내지말구  나라를위해  계속 일할수있게해주시면좋겠네요  부채도많은데~\nBT...
# 892   2020-09-01 03:06:29                         그동안 고생했네 방탄소년단ㆍ아미ㆍ빅히트 축하축하
# 279   2020-09-01 05:57:47                                               오 대박
#
#      press                                        title  \
# 1122   KBS        BTS ‘다이너마이트’ 빌보드 핫100 1위 등극…한국 뮤지션 최초
# 914   경향신문  BTS, 한국 가수 최초 미 빌보드 싱글차트 1위···‘다이너마이트’급 대기록
# 514    뉴시스           BTS '다이너마이트' 빌보드 '핫100' 1위…한국가수 최초
# 892   경향신문  BTS, 한국 가수 최초 미 빌보드 싱글차트 1위···‘다이너마이트’급 대기록
# 279   중앙일보          BTS '다이너마이트' 터졌다···韓 가수 최초 빌보드 싱글1위
#
#                                                     url
# 1122  https://news.naver.com/main/read.nhn?mode=LSD&...
# 914   https://news.naver.com/main/read.nhn?mode=LSD&...
# 514   https://news.naver.com/main/read.nhn?mode=LSD&...
# 892   https://news.naver.com/main/read.nhn?mode=LSD&...
# 279   https://news.naver.com/main/read.nhn?mode=LSD&...

# %%
df.reply[:10]
# Out:
# 0                                    국보소년단<U+0001F49C>
# 1                                         아줌마가 들어도 좋더라
# 2    팩트체크\n\n현재 빌보드 HOT 100\n\n1위  방탄소년단[BTS]\n2위 C...
# 3              방탄소년단이 한국사람이라 너무 자랑스러워요 ㅠㅠ 우리오래오래 함께하자!
# 4                  대단한 BTS, 월드 클래스는 다르네^^ 좋은 소식!! 응원해요
# 5                        정국오빠 생일과 더불어 빌보드 1위기사라니ㅠㅠ축제구나
# 6    정말 축하하고 응원하지만\n집에서 여러 계정으로 스트리밍 돌리고 사재기하고 다른 팬...
# 7                         기자는 자고 일어났지만, 팬들은 못자고 발표 기다림
# 8                                자랑스럽다!!!!!! 축하합니다!!!!
# 9                                 SuperM 늘 응원하고 사랑합니다~
# Name: reply, dtype: object

# %%
df['reply'].str.replace('[^가-힣]', ' ', regex = True)
# Out:
# 0                                       국보소년단
# 1                                            아줌마가 들어도 좋더라
# 2       팩트체크  현재 빌보드           위  방탄소년단       위       ...
# 3                 방탄소년단이 한국사람이라 너무 자랑스러워요    우리오래오래 함께하자
# 4                     대단한      월드 클래스는 다르네   좋은 소식   응원해요
#                               ...
# 1195                                       역시
# 1196    우리 탄이들 너무 자랑스럽고 사랑해                           ...
# 1197                               이런애들 꼭 군대를 보내 는게  맞을까요
# 1198                                            군면제급이다 이건
# 1199    자랑스러워요 정말   축하해 김남준 김석진 민윤기 정호석 박지민 김태형 전정국   ...
# Name: reply, Length: 1200, dtype: object

# %%
df['reply'] = df['reply'].str.replace('[^가-힣]', ' ', regex = True)
df['reply'].sample(5)
# Out:
# 1193                          위 했으니 군면제 해주자  국위선양 공로가크다
# 484                                            대단하네 진짜
# 46          방탄 축하행
# 973                                           진짜 최고다 진짜
# 1061    옛날로 치면 신화    같은 그룹인데 세계에서 인기가 통하다니 참으로 미스테리 하군요
# Name: reply, dtype: object

# %%
from konlpy.tag import Hannanum
han = Hannanum()
han.nouns(u'질문이나 건의사항은 깃헙 이슈 트레커에 남겨주세요.')
# Out:
# ['질문', '건의사항', '깃헙', '이슈', '트레커']

# %%
from konlpy.tag import Kkma
kkma = Kkma()
kkma.nouns(u'질문이나 건의사항은 깃헙 이슈 트레커에 남겨주세요.')
# Out:
# ['질문', '건의', '건의사항', '사항', '깃헙', '이슈', '트레커']

# %%
mydf = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
mydf
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
dfs = mydf.apply(lambda x: x**2)
dfs
# Out:
#    A   B
# 0  1  16
# 1  4  25
# 2  9  36

# %%
mydf.apply(lambda x: x + 2)
# Out:
#    A  B
# 0  3  6
# 1  4  7
# 2  5  8

# %%
df['reply'].sample(5)
# Out:
# 296             강경화 자리에 방탄소년단을
# 522               과분한 자리네 실력에 비해
# 624    저랑  제딸도   과일에서  매일  듣고  있어요
# 390          와 카디비를 이렇게 빨리 재끼다니
# 895                  방탄 너희가 최고야
# Name: reply, dtype: object

# %%
nouns = df['reply'].apply(kkma.nouns)
nouns
# Out:
# 0                                        [국보, 국보소년단, 소년단]
# 1                                                   [아줌마]
# 2                   [팩트, 팩트체크, 체크, 보드, 위, 방탄, 방탄소년단, 소년단]
# 3              [방탄, 방탄소년단, 소년단, 한국, 한국사람, 사람, 자랑, 우리, 하자]
# 4                                       [월드, 클래스, 소식, 응원]
#                               ...
# 1195                                                   []
# 1196                                      [우리, 탄, 자랑, 사랑]
# 1197                                              [애, 군대]
# 1198                                     [군, 군면제급, 면제, 급]
# 1199    [자랑, 축하, 김, 김남, 남, 김석진, 민, 민윤기, 윤기, 정, 정호석, 호석...
# Name: reply, Length: 1200, dtype: object

# %%
nouns = nouns.explode()
nouns
# Out:
# 0          국보
# 0       국보소년단
# 0         소년단
# 1         아줌마
# 2          팩트
#         ...
# 1199      박지민
# 1199      김태형
# 1199        전
# 1199      전정국
# 1199       정국
# Name: reply, Length: 9353, dtype: object

# %%
test = pd.DataFrame({'A': [[1, 2, 3], 'foo', [], [3, 4]], 'B': 1,
                     'C': [['a', 'b', 'c'], np.nan, [], ['d', 'e']]})
test
# Out:
#            A  B          C
# 0  [1, 2, 3]  1  [a, b, c]
# 1        foo  1        NaN
# 2         []  1         []
# 3     [3, 4]  1     [d, e]

# %%
test.explode('A') # 기말 시험 예상
# Out:
#      A  B          C
# 0    1  1  [a, b, c]
# 0    2  1  [a, b, c]
# 0    3  1  [a, b, c]
# 1  foo  1        NaN
# 2  NaN  1         []
# 3    3  1     [d, e]
# 3    4  1     [d, e]

# %%
test
# Out:
#            A  B          C
# 0  [1, 2, 3]  1  [a, b, c]
# 1        foo  1        NaN
# 2         []  1         []
# 3     [3, 4]  1     [d, e]

# %%
test.explode(['A', 'C']) # 기말 시험 예상
# Out:
#      A  B    C
# 0    1  1    a
# 0    2  1    b
# 0    3  1    c
# 1  foo  1  NaN
# 2  NaN  1  NaN
# 3    3  1    d
# 3    4  1    e

# %%
test.explode(['A', 'C']) # 기말 시험 예상
# Out:
#      A  B    C
# 0    1  1    a
# 0    2  1    b
# 0    3  1    c
# 1  foo  1  NaN
# 2  NaN  1  NaN
# 3    3  1    d
# 3    4  1    e

# %%
df_word = pd.DataFrame({'word': nouns})
df_word.sample(5)
# Out:
#      word
# 26      군
# 30      광
# 19     내가
# 667    미국
# 1140   문통

# %%
df_word['len'] = df_word['word'].str.len()
df_word = df_word.query('len >= 2')
df_word.sample(5)
# Out:
#      word  len
# 204    기분  2.0
# 847    다운  2.0
# 1100   흑인  2.0
# 423    자랑  2.0
# 744    케이  2.0

# %%
df_word.query('word == "소년단"')
# Out:
#      word  len
# 0     소년단  3.0
# 2     소년단  3.0
# 3     소년단  3.0
# 27    소년단  3.0
# 29    소년단  3.0
# ...   ...  ...
# 1123  소년단  3.0
# 1159  소년단  3.0
# 1162  소년단  3.0
# 1164  소년단  3.0
# 1176  소년단  3.0
#
# [144 rows x 2 columns]

# %%
df_word = df_word.groupby('word', as_index=False) \
                 .agg(n = ('word', 'count')) \
                 .sort_values('n', ascending=False)
df_word
# Out:
#        word    n
# 752      방탄  280
# 1878     축하  236
# 1556     자랑  205
# 1032    소년단  144
# 763   방탄소년단  136
# ...     ...  ...
# 2140     활용    1
# 2141     황금    1
# 2142   황금막내    1
# 2143     회사    1
# 2144     회수    1
#
# [2168 rows x 2 columns]

# %%
top20 = df_word.head(20)
top20
# Out:
#        word    n
# 752      방탄  280
# 1878     축하  236
# 1556     자랑  205
# 1032    소년단  144
# 763   방탄소년단  136
# 813      보드  131
# 618      면제  125
# 233     군면제   78
# 225      군대   77
# 1364     우리   68
# 11       가수   64
# 987      선양   62
# 215    국위선양   59
# 214      국위   58
# 328      나라   53
# 2038     한국   52
# 371      노래   50
# 708      민국   46
# 462      대한   46
# 463    대한민국   46

# %%
plt.figure(figsize=(6, 4))
sns.barplot(data=top20, y='word', x='n', hue='word');

# %%
from PIL import Image
icon = Image.open('data/cloud.png')

img = Image.new('RGB', icon.size, (255, 255, 255))
img.paste(icon, icon)

img = np.array(img)
img
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
df_word.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2168 entries, 752 to 2144
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   word    2168 non-null   object
#  1   n       2168 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 50.8+ KB

# %%
df_word.sample(5)
# Out:
#       word  n
# 504     등판  1
# 1476   이만큼  1
# 1726    주요  1
# 2020  필요하다  1
# 682     물뽕  1

# %%
dic_word = df_word.set_index('word').to_dict()['n']
dic_word
# Out:
# {'방탄': 280,
#  '축하': 236,
#  '자랑': 205,
#  '소년단': 144,
#  '방탄소년단': 136,
#  '보드': 131,
#  '면제': 125,
#  '군면제': 78,
#  '군대': 77,
#  '우리': 68,
#  '가수': 64,
#  '선양': 62,
#  '국위선양': 59,
#  '국위': 58,
#  '나라': 53,
#  '한국': 52,
#  '노래': 50,
#  '민국': 46,
#  '대한': 46,
#  '대한민국': 46,
#  '진짜': 43,
#  '최고': 40,
#  '대박': 39,
#  '세계': 36,
#  '아미': 35,
#  '소식': 31,
#  '시기': 30,
#  '생각': 30,
#  '사람': 29,
#  '정국': 29,
#  '행복': 29,
#  '라니': 29,
#  '역사': 28,
#  '사랑': 28,
#  '코로나': 27,
#  '차트': 27,
#  '생일': 27,
#  '핫백': 26,
#  '감사': 24,
#  '위라니': 24,
#  '우리나라': 23,
#  '축하해': 23,
#  '미국': 22,
#  '이것': 22,
#  '전세계': 22,
#  '싱글': 22,
#  '인정': 22,
#  '그룹': 22,
#  '진심': 22,
#  '정도': 22,
#  '노력': 21,
#  '응원': 20,
#  '활동': 19,
#  '음악': 19,
#  '요즘': 19,
#  '고생': 18,
#  '최초': 17,
#  '아이': 17,
#  '올림픽': 15,
#  '너희': 15,
#  '문화': 15,
#  '이제': 15,
#  '국민': 15,
#  '때문': 15,
#  '국가': 15,
#  '뉴스': 15,
#  '기사': 14,
#  '수고': 14,
#  '숟가락': 14,
#  '내가': 14,
#  '대통령': 14,
#  '멤버': 14,
#  '기분': 14,
#  '시국': 13,
#  '아티스트': 13,
#  '이름': 13,
#  '한국인': 13,
#  '눈물': 13,
#  '지금': 12,
#  '마이트': 12,
#  '아시아': 12,
#  '금메달': 12,
#  '댓글': 12,
#  '친구': 11,
#  '남자': 11,
#  '국뽕': 11,
#  '기록': 11,
#  '싱글차트': 11,
#  '재인': 11,
#  '위로': 11,
#  '대표': 10,
#  '선물': 10,
#  '마라': 10,
#  '다이': 10,
#  '사상': 10,
#  '병역': 10,
#  '하나': 10,
#  '시대': 10,
#  '국내': 10,
#  '문재인': 10,
#  '얘기': 9,
#  '케이': 9,
#  '역사상': 9,
#  '희망': 9,
#  '인기': 9,
#  '하다': 9,
#  '그것': 9,
#  '재앙': 9,
#  '진정': 9,
#  '만큼': 9,
#  '하루': 9,
#  '이번': 9,
#  '의미': 8,
#  '위상': 8,
#  '아이돌': 8,
#  '세계적': 8,
#  '애국': 8,
#  '청와대': 8,
#  '홍보': 8,
#  '정상': 8,
#  '시절': 8,
#  '데뷔': 8,
#  '경사': 8,
#  '콩쿨': 8,
#  '덕분': 8,
#  '계속': 8,
#  '오늘': 8,
#  '가사': 8,
#  '케이팝': 8,
#  '하자': 8,
#  '동안': 8,
#  '소름': 7,
#  '의무': 7,
#  '이상': 7,
#  '자리': 7,
#  '실력': 7,
#  '일본': 7,
#  '감격': 7,
#  '얘들': 7,
#  '월드컵': 7,
#  '경제': 7,
#  '정치': 7,
#  '효과': 7,
#  '여기': 7,
#  '영향력': 7,
#  '한국가수': 7,
#  '단하': 7,
#  '한번': 7,
#  '다이너마이트': 7,
#  '보이': 7,
#  '앨범': 7,
#  '영광': 6,
#  '외국': 6,
#  '외교': 6,
#  '건강': 6,
#  '밴드': 6,
#  '모두': 6,
#  '다음': 6,
#  '가치': 6,
#  '독도': 6,
#  '아침': 6,
#  '멜론': 6,
#  '거지': 6,
#  '쾌거': 6,
#  '결국': 6,
#  '누구': 6,
#  '월드': 6,
#  '블랙': 6,
#  '사이': 6,
#  '우울': 6,
#  '하면': 6,
#  '기간': 6,
#  '수가': 6,
#  '아들': 6,
#  '처음': 6,
#  '순위': 6,
#  '영어': 6,
#  '이젠': 6,
#  '동시대': 6,
#  '마음': 6,
#  '세금': 6,
#  '축하축하': 5,
#  '메달': 5,
#  '트롯': 5,
#  '와우': 5,
#  '경제적': 5,
#  '거기': 5,
#  '업적': 5,
#  '영원': 5,
#  '히트': 5,
#  '역사적': 5,
#  '발표': 5,
#  '문제': 5,
#  '대상': 5,
#  '여러분': 5,
#  '결과': 5,
#  '대중': 5,
#  '필요': 5,
#  '무엇': 5,
#  '개월': 5,
#  '완전': 5,
#  '니들': 5,
#  '추카': 5,
#  '이거': 5,
#  '보유국': 5,
#  '기자': 5,
#  '성장': 5,
#  '기생충': 5,
#  '주세': 5,
#  '아무': 5,
#  '나이': 5,
#  '메인': 5,
#  '진입': 5,
#  '국격': 5,
#  '애국자': 5,
#  '국가대표': 5,
#  '청년': 5,
#  '도움': 5,
#  '존경': 5,
#  '속보': 5,
#  '스타': 5,
#  '기쁨': 5,
#  '시민': 5,
#  '시작': 5,
#  '군대면': 5,
#  '순간': 5,
#  '기부': 5,
#  '그래미': 5,
#  '레전': 5,
#  '시간': 5,
#  '훈련': 5,
#  '가요': 5,
#  '여자': 5,
#  '해외': 5,
#  '방시혁': 4,
#  '해라': 4,
#  '가지': 4,
#  '그대': 4,
#  '혜택': 4,
#  '감동': 4,
#  '가슴': 4,
#  '인생': 4,
#  '정부': 4,
#  '군사': 4,
#  '군대면제': 4,
#  '국방': 4,
#  '국제': 4,
#  '실화': 4,
#  '기대': 4,
#  '자체': 4,
#  '자기': 4,
#  '재능': 4,
#  '문씨': 4,
#  '병역면제': 4,
#  '영국': 4,
#  '얘네들': 4,
#  '경제효과': 4,
#  '모습': 4,
#  '사회': 4,
#  '나중': 4,
#  '나의': 4,
#  '이래': 4,
#  '추카추카': 4,
#  '유명': 4,
#  '내가수': 4,
#  '비틀즈': 4,
#  '비교': 4,
#  '초청': 4,
#  '축구': 4,
#  '챠트': 4,
#  '중요': 4,
#  '꽃길': 4,
#  '이유': 4,
#  '이용': 4,
#  '기회': 4,
#  '대체': 4,
#  '주자': 4,
#  '주라': 4,
#  '선수': 4,
#  '새벽': 4,
#  '성과': 4,
#  '세상': 4,
#  '이후': 4,
#  '기초': 4,
#  '마지막': 4,
#  '손실': 4,
#  '존재': 4,
#  '힐링': 4,
#  '영화': 4,
#  '팬덤': 4,
#  '문통': 4,
#  '방시': 4,
#  '한글': 4,
#  '문재앙': 4,
#  '번째': 4,
#  '무대': 4,
#  '발매': 4,
#  '예술': 4,
#  '투표': 4,
#  '종일': 3,
#  '국보': 3,
#  '국가적': 3,
#  '딴것': 3,
#  '입대': 3,
#  '리스트': 3,
#  '정신': 3,
#  '라디오': 3,
#  '스타일': 3,
#  '해주자': 3,
#  '현실': 3,
#  '하세': 3,
#  '가야': 3,
#  '가요계': 3,
#  '휴가': 3,
#  '그동안': 3,
#  '승승장구': 3,
#  '스포츠': 3,
#  '신곡': 3,
#  '시장': 3,
#  '강남스타일': 3,
#  '강경': 3,
#  '하루종일': 3,
#  '군인': 3,
#  '국익': 3,
#  '정권': 3,
#  '국회': 3,
#  '수십': 3,
#  '디피씨': 3,
#  '국방부': 3,
#  '쓰럽': 3,
#  '기초군사훈련': 3,
#  '쟤들': 3,
#  '적폐': 3,
#  '시상식': 3,
#  '상상': 3,
#  '의사': 3,
#  '애국시민': 3,
#  '준호': 3,
#  '지네': 3,
#  '청춘': 3,
#  '이도': 3,
#  '데뷔때': 3,
#  '아시아인': 3,
#  '막내': 3,
#  '아저씨': 3,
#  '주면': 3,
#  '인간적': 3,
#  '삼성': 3,
#  '성적': 3,
#  '생활': 3,
#  '성공': 3,
#  '어디': 3,
#  '최소': 3,
#  '빅히트': 3,
#  '블랙핑크': 3,
#  '코로나때문': 3,
#  '카디비': 3,
#  '대형': 3,
#  '대회': 3,
#  '사고': 3,
#  '안해': 3,
#  '유일': 3,
#  '참고': 3,
#  '찬성': 3,
#  '관왕': 3,
#  '최근': 3,
#  '공연': 3,
#  '유튜브': 3,
#  '사벽': 3,
#  '요새': 3,
#  '얼굴': 3,
#  '느낌': 3,
#  '보이그룹': 3,
#  '우승': 3,
#  '완벽': 3,
#  '보답': 3,
#  '넘사벽': 3,
#  '보고': 3,
#  '본인': 3,
#  '복무': 3,
#  '보이밴드': 3,
#  '년만': 3,
#  '얘네': 3,
#  '오빠': 3,
#  '영어권': 3,
#  '큰일': 3,
#  '파이': 3,
#  '파이팅': 3,
#  '튜브': 3,
#  '특별': 3,
#  '겹경사': 3,
#  '대중가요': 3,
#  '언론': 3,
#  '보드차트': 3,
#  '보드핫백': 3,
#  '걱정': 3,
#  '게임': 3,
#  '표현': 3,
#  '옛날': 3,
#  '방법': 3,
#  '한국어': 3,
#  '병무청': 3,
#  '오랜만': 3,
#  '외화': 3,
#  '다행': 3,
#  '예전': 3,
#  '핑크': 3,
#  '다이나': 3,
#  '다이나마이트': 3,
#  '간만': 3,
#  '역할': 3,
#  '미국인': 3,
#  '미스': 3,
#  '가도': 3,
#  '가능': 3,
#  '가보': 2,
#  '가게': 2,
#  '감사해': 2,
#  '홍보대사': 2,
#  '행사': 2,
#  '거리': 2,
#  '갱신': 2,
#  '개판': 2,
#  '개인적': 2,
#  '한명': 2,
#  '방포': 2,
#  '방탄주': 2,
#  '문화적': 2,
#  '문죄인': 2,
#  '방탄보유국': 2,
#  '벌이': 2,
#  '버스': 2,
#  '백만': 2,
#  '병역특례': 2,
#  '파급': 2,
#  '포방포': 2,
#  '우리나라가수': 2,
#  '외화벌이': 2,
#  '워드': 2,
#  '언플': 2,
#  '억정': 2,
#  '대중성': 2,
#  '대신': 2,
#  '어이': 2,
#  '여건': 2,
#  '엑스': 2,
#  '에스': 2,
#  '영웅': 2,
#  '오랫만': 2,
#  '다운': 2,
#  '영상': 2,
#  '열광': 2,
#  '유럽': 2,
#  '넘버원': 2,
#  '음악적': 2,
#  '암울': 2,
#  '안티': 2,
#  '안보': 2,
#  '안됨': 2,
#  '운동선수': 2,
#  '운동': 2,
#  '년전': 2,
#  '위기': 2,
#  '월드스타': 2,
#  '윈윈': 2,
#  '위치': 2,
#  '네이버': 2,
#  '누구도': 2,
#  '이의': 2,
#  '기간동안': 2,
#  '기획사': 2,
#  '돌이': 2,
#  '독보적': 2,
#  '도로': 2,
#  '아시안': 2,
#  '악플러들': 2,
#  '의원': 2,
#  '김석진': 2,
#  '난리': 2,
#  '나스': 2,
#  '나무': 2,
#  '음원': 2,
#  '이랑': 2,
#  '위버스': 2,
#  '인사': 2,
#  '인물': 2,
#  '인권': 2,
#  '인간': 2,
#  '이해': 2,
#  '아시아가수': 2,
#  '아빠': 2,
#  '덤핑': 2,
#  '등극': 2,
#  '드로': 2,
#  '아이디': 2,
#  '기업': 2,
#  '기억': 2,
#  '끝물': 2,
#  '꼰대': 2,
#  '이정': 2,
#  '작년': 2,
#  '인지도': 2,
#  '인재': 2,
#  '기본적': 2,
#  '인성': 2,
#  '일위': 2,
#  '일본인': 2,
#  '자랑쓰런': 2,
#  '실시간': 2,
#  '동급': 2,
#  '디피': 2,
#  '아니쥬': 2,
#  '쓰럽게': 2,
#  '기적': 2,
#  '기자분': 2,
#  '기여': 2,
#  '그네': 2,
#  '전원': 2,
#  '전역': 2,
#  '시고': 2,
#  '로드': 2,
#  '레전드로': 2,
#  '레전드': 2,
#  '래요': 2,
#  '신경': 2,
#  '자원': 2,
#  '자신': 2,
#  '자부심': 2,
#  '글로벌': 2,
#  '근무': 2,
#  '재능기부': 2,
#  '잘못': 2,
#  '전드': 2,
#  '전달': 2,
#  '전국민': 2,
#  '정국이도': 2,
#  '젊은이': 2,
#  '국적': 2,
#  '전정국': 2,
#  '정수기': 2,
#  '라도': 2,
#  '마니': 2,
#  '리얼': 2,
#  '리스펙': 2,
#  '리스': 2,
#  '스트리밍': 2,
#  '그래미상': 2,
#  '그때': 2,
#  '제일': 2,
#  '국보급': 2,
#  '제목': 2,
#  '손흥민': 2,
#  '소통': 2,
#  '마이클잭': 2,
#  '마이클': 2,
#  '수식어': 2,
#  '수상': 2,
#  '정말': 2,
#  '국제콩쿨': 2,
#  '제대': 2,
#  '정치적': 2,
#  '정치인': 2,
#  '정치얘기': 2,
#  '전부': 2,
#  '머리': 2,
#  '말자': 2,
#  '생일선물': 2,
#  '생일날': 2,
#  '설명': 2,
#  '선배': 2,
#  '세계문화': 2,
#  '마세': 2,
#  '만이': 2,
#  '소년': 2,
#  '소개': 2,
#  '세계인': 2,
#  '정작': 2,
#  '정의': 2,
#  '조선': 2,
#  '조금': 2,
#  '지붕': 2,
#  '주고': 2,
#  '주가': 2,
#  '죄인': 2,
#  '국격과': 2,
#  '국개의원': 2,
#  '국가홍보': 2,
#  '주의': 2,
#  '주신': 2,
#  '주시': 2,
#  '주변': 2,
#  '상승': 2,
#  '선구자': 2,
#  '생일축하': 2,
#  '멋지네': 2,
#  '머리카락': 2,
#  '축제': 2,
#  '취향': 2,
#  '사건': 2,
#  '메세지': 2,
#  '철수': 2,
#  '광고': 2,
#  '관련주': 2,
#  '관광객': 2,
#  '초대': 2,
#  '주모': 2,
#  '지도': 2,
#  '증명': 2,
#  '과거': 2,
#  '구도': 2,
#  '교육': 2,
#  '지원': 2,
#  '칭찬': 2,
#  '콘서트': 2,
#  '컴백': 2,
#  '부탁': 2,
#  '부존자원': 2,
#  '부족': 2,
#  '부담': 2,
#  '봉준호': 2,
#  '메달딴것': 2,
#  '명곡': 2,
#  '빈국': 2,
#  '빅뱅': 2,
#  '비티에스': 2,
#  '고민': 2,
#  '공익': 2,
#  '공부': 2,
#  '클래식': 2,
#  '격과': 2,
#  '경제적효과': 2,
#  '경제적가치': 2,
#  '테러': 2,
#  '텃세': 2,
#  '파구': 2,
#  '무능': 2,
#  '목적': 2,
#  '모름': 2,
#  '본고장': 2,
#  '축하해용': 2,
#  '공감': 2,
#  '곳곳': 2,
#  '고통': 2,
#  '고장': 2,
#  '평생': 2,
#  '피땀': 2,
#  '개인': 2,
#  '하지': 2,
#  '벤치': 2,
#  '모든': 2,
#  '문대통령': 2,
#  '보물': 2,
#  '보드핫': 2,
#  '보드싱글': 2,
#  '특례': 2,
#  '경비대': 2,
#  '겸손': 2,
#  '팩트': 2,
#  '탄주': 2,
#  '키즈': 2,
#  '바리': 2,
#  '힘내': 2,
#  '바래요': 2,
#  '바다': 2,
#  '미스터': 2,
#  '뮤지션': 2,
#  '뮤비': 2,
#  '반대': 2,
#  '반감': 2,
#  '방탄때문': 2,
#  '한남': 2,
#  '해용': 2,
#  '강제': 2,
#  '강남': 2,
#  '행보': 2,
#  '해주고': 2,
#  '능가': 2,
#  '단비': 2,
#  '단군이래': 2,
#  '단군': 2,
#  '연예인': 2,
#  '대사': 2,
#  '당신': 2,
#  '연기': 2,
#  '역대': 2,
#  '후보': 2,
#  '획득': 2,
#  '훈장': 2,
#  '훈련소': 2,
#  '가수라니': 2,
#  '믹스': 2,
#  '박수': 2,
#  '가격': 1,
#  '가락': 1,
#  '후회': 1,
#  '후원': 1,
#  '가짜뉴스': 1,
#  '각종': 1,
#  '간에': 1,
#  '갈말': 1,
#  '갈말읍': 1,
#  '감독': 1,
#  '감사하다': 1,
#  '활동시기': 1,
#  '활동임': 1,
#  '활력': 1,
#  '홍보도': 1,
#  '홍보사진': 1,
#  '화가': 1,
#  '화력': 1,
#  '화이팅': 1,
#  '화이팅되': 1,
#  '박이': 1,
#  '미스테리': 1,
#  '미스트롯': 1,
#  '미제': 1,
#  '미쳣': 1,
#  '미쿡': 1,
#  '미쿡서': 1,
#  '미통닭': 1,
#  '미필': 1,
#  '믹스테잎': 1,
#  '민간': 1,
#  '민간외교': 1,
#  '민도': 1,
#  '민방위': 1,
#  '민스트라': 1,
#  '물건': 1,
#  '뭉디': 1,
#  '뮤직': 1,
#  '미국령': 1,
#  '미래': 1,
#  '미분': 1,
#  '미스터트롯': 1,
#  '문제인': 1,
#  '문죄': 1,
#  '민지': 1,
#  '밑바닥': 1,
#  '바닥': 1,
#  '바디': 1,
#  '바디친구밖': 1,
#  '바람': 1,
#  '박그네': 1,
#  '박약': 1,
#  '박장': 1,
#  '박장대소': 1,
#  '박지': 1,
#  '박지민': 1,
#  '박진영': 1,
#  '반값': 1,
#  '반만큼': 1,
#  '반백': 1,
#  '반백살': 1,
#  '반영': 1,
#  '발라드': 1,
#  '밥상': 1,
#  '민윤기': 1,
#  '민주': 1,
#  '민주인사': 1,
#  '물타기': 1,
#  '방탄이면': 1,
#  '방탄이후': 1,
#  '방탄축하': 1,
#  '방탄팬': 1,
#  '배경': 1,
#  '방기': 1,
#  '방뽕': 1,
#  '방송': 1,
#  '방송국': 1,
#  '방영': 1,
#  '방탄기사': 1,
#  '방탄노래': 1,
#  '방탄도': 1,
#  '방탄만큼': 1,
#  '방탄만큼하면': 1,
#  '방탄맘': 1,
#  '문통과': 1,
#  '문프': 1,
#  '문학': 1,
#  '문화외교가': 1,
#  '문화외교관': 1,
#  '문화전파': 1,
#  '문화쪽': 1,
#  '문화훈장': 1,
#  '무료': 1,
#  '무스': 1,
#  '무시': 1,
#  '방탄소년단과': 1,
#  '방탄소년단분': 1,
#  '방탄소식임': 1,
#  '방탄아이': 1,
#  '방탄애': 1,
#  '병역기간동안': 1,
#  '병역혜택': 1,
#  '배우기': 1,
#  '배우자': 1,
#  '배철수': 1,
#  '백만배': 1,
#  '백배': 1,
#  '백성': 1,
#  '백스트리트': 1,
#  '백인': 1,
#  '밴드중': 1,
#  '버전': 1,
#  '번갈': 1,
#  '방탄소녀단': 1,
#  '방탄소년': 1,
#  '문죄앙': 1,
#  '범죄': 1,
#  '무용': 1,
#  '무작정': 1,
#  '무지': 1,
#  '문꼰대': 1,
#  '문장': 1,
#  '문재': 1,
#  '문재인대통령': 1,
#  '문재인아': 1,
#  '모든분': 1,
#  '범주': 1,
#  '법안': 1,
#  '법원': 1,
#  '벙역': 1,
#  '변신': 1,
#  '변절자': 1,
#  '모범': 1,
#  '모병': 1,
#  '모집하겠숩': 1,
#  '모형': 1,
#  '목표': 1,
#  '무늬': 1,
#  '무당': 1,
#  '멤버간': 1,
#  '보도': 1,
#  '보드도': 1,
#  '보믄': 1,
#  '보배': 1,
#  '보삼': 1,
#  '보셈': 1,
#  '범접': 1,
#  '범접불가': 1,
#  '부여': 1,
#  '부정': 1,
#  '부채': 1,
#  '북미': 1,
#  '보약': 1,
#  '보여': 1,
#  '보유': 1,
#  '보이밴드중': 1,
#  '보이스': 1,
#  '보태': 1,
#  '보탬': 1,
#  '보호': 1,
#  '본적': 1,
#  '병장': 1,
#  '보내다': 1,
#  '모든이': 1,
#  '불과': 1,
#  '불만': 1,
#  '불매': 1,
#  '불매운동': 1,
#  '불쌍': 1,
#  '브라더스': 1,
#  '브랜드': 1,
#  '브로마이드': 1,
#  '브리트': 1,
#  '볼일': 1,
#  '봉사': 1,
#  '봉사역할': 1,
#  '봉준호감독': 1,
#  '부대': 1,
#  '부르노마스': 1,
#  '부모': 1,
#  '비난': 1,
#  '비난글': 1,
#  '비들': 1,
#  '비례': 1,
#  '비례대표': 1,
#  '비리': 1,
#  '비버': 1,
#  '비상': 1,
#  '비상업적활동': 1,
#  '분과': 1,
#  '분야': 1,
#  '분탕': 1,
#  '분홍': 1,
#  '불가': 1,
#  '불가능': 1,
#  '불공정': 1,
#  '블랙아이': 1,
#  '면제감': 1,
#  '면제대상': 1,
#  '면제리스트': 1,
#  '면제인거잖': 1,
#  '면죄': 1,
#  '명부': 1,
#  '명사': 1,
#  '명예': 1,
#  '몇백만': 1,
#  '몇십': 1,
#  '모너': 1,
#  '모너모': 1,
#  '메달획득': 1,
#  '블랙코메디': 1,
#  '블럭': 1,
#  '사건임': 1,
#  '사단': 1,
#  '사단장': 1,
#  '사단장급': 1,
#  '비엔나': 1,
#  '비웃음': 1,
#  '비의': 1,
#  '비즈니스': 1,
#  '비타민': 1,
#  '비튀': 1,
#  '비티엑스': 1,
#  '비하': 1,
#  '빈집': 1,
#  '빈집털이': 1,
#  '빠리': 1,
#  '블랙리스트': 1,
#  '사유': 1,
#  '사이다': 1,
#  '사재기': 1,
#  '사절': 1,
#  '사주': 1,
#  '사주기초훈련': 1,
#  '사진': 1,
#  '사탄': 1,
#  '빠져': 1,
#  '빨갱이': 1,
#  '빼액': 1,
#  '뻘짓': 1,
#  '뻘짖': 1,
#  '뻘짖거리': 1,
#  '뽕짝': 1,
#  '사가': 1,
#  '메시지': 1,
#  '메이슨': 1,
#  '메이저': 1,
#  '메이커': 1,
#  '메인뉴스': 1,
#  '메인싱글': 1,
#  '메인음원차트': 1,
#  '메인차트': 1,
#  '멜로디': 1,
#  '멜론차트': 1,
#  '말기': 1,
#  '말길': 1,
#  '말대': 1,
#  '사생활': 1,
#  '사실': 1,
#  '사용': 1,
#  '생시': 1,
#  '사회주의': 1,
#  '사회지도층': 1,
#  '살맛': 1,
#  '삼성오너일가': 1,
#  '삼성전자': 1,
#  '상과': 1,
#  '상관': 1,
#  '상금': 1,
#  '상남자': 1,
#  '상도': 1,
#  '상를': 1,
#  '상상이상': 1,
#  '상습': 1,
#  '사막': 1,
#  '사모님': 1,
#  '서양가수': 1,
#  '서양인': 1,
#  '서울': 1,
#  '선가': 1,
#  '선두': 1,
#  '상업적': 1,
#  '상접': 1,
#  '상징': 1,
#  '상한': 1,
#  '상한가': 1,
#  '새꾸': 1,
#  '새끼': 1,
#  '새벽내': 1,
#  '생각지도': 1,
#  '생계': 1,
#  '생선': 1,
#  '생일도': 1,
#  '말로': 1,
#  '망정': 1,
#  '맞져': 1,
#  '매니아': 1,
#  '매매': 1,
#  '매인': 1,
#  '매인탑뉴스': 1,
#  '먹자': 1,
#  '멍충이': 1,
#  '막강': 1,
#  '막내딸': 1,
#  '생일추카': 1,
#  '생활면': 1,
#  '생활속': 1,
#  '서양': 1,
#  ...}

# %%
wc = WordCloud(random_state=1234, font_path=FONT_PATH,
               width = 400, height = 400, background_color='white',
               mask = img)

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
imgWC = wc.generate_from_frequencies(dic_word)
plt.figure(figsize=(6, 4));
plt.axis('off')
plt.imshow(imgWC);

# %% [markdown]
# # 기말고사 예상

# %%
import pandas as pd

df = pd.DataFrame({
    'A': [1, 2, 3],
    'B': [10, 20, 30]
})
df
# Out:
#    A   B
# 0  1  10
# 1  2  20
# 2  3  30

# %%
# 각 열의 최대값에서 최소값을 뺀 결과
print(df.apply(lambda x: x.max() - x.min(), axis=0))
# Out:
# A     2
# B    20
# dtype: int64

# %%
# 각 열의 최대값에서 최소값을 뺀 결과
print(df.apply(lambda x: x.max() - x.min()))
# Out:
# A     2
# B    20
# dtype: int64

# %%
# 각 열의 최대값에서 최소값을 뺀 결과
print(df.apply(lambda x: x.max() - x.min(), axis=1))
# Out:
# 0     9
# 1    18
# 2    27
# dtype: int64

# %%
df
# Out:
#    A   B
# 0  1  10
# 1  2  20
# 2  3  30

# %%
f = lambda x: x + 5
df.apply(f)
# Out:
#    A   B
# 0  6  15
# 1  7  25
# 2  8  35

# %%
f = lambda x: x * 5
df.apply(f, axis=1)
# Out:
#     A    B
# 0   5   50
# 1  10  100
# 2  15  150

# %%
f = lambda x: x / 5
df.apply(f, axis=1)
# Out:
#      A    B
# 0  0.2  2.0
# 1  0.4  4.0
# 2  0.6  6.0

# %%
# 각 행의 평균 구하기
print(df.apply(lambda x: x.mean(), axis=1))
# Out:
# 0     5.5
# 1    11.0
# 2    16.5
# dtype: float64

# %%
# 각 열의 평균 구하기
print(df.apply(lambda x: x.mean(), axis=0))
# Out:
# A     2.0
# B    20.0
# dtype: float64

# %%
df
# Out:
#    A   B
# 0  1  10
# 1  2  20
# 2  3  30

# %%
df.apply(lambda x: x.sum(), axis=0)
# Out:
# A     6
# B    60
# dtype: int64

# %%
df.apply(sum, axis=0)
# Out:
# A     6
# B    60
# dtype: int64

# %%
df.apply(sum, axis=1)
# Out:
# 0    11
# 1    22
# 2    33
# dtype: int64

# %%
df.sum(axis=0)
# Out:
# A     6
# B    60
# dtype: int64

# %%
df.sum(axis=1)
# Out:
# 0    11
# 1    22
# 2    33
# dtype: int64

# %%
import pandas as pd

df = pd.DataFrame({
    'name': ['Alice', 'Bob'],
    'hobbies': [['reading', 'cooking'], ['gaming']]
})
df
# Out:
#     name             hobbies
# 0  Alice  [reading, cooking]
# 1    Bob            [gaming]

# %%
# explode 적용
df_exploded = df.explode('hobbies')
df_exploded
# Out:
#     name  hobbies
# 0  Alice  reading
# 0  Alice  cooking
# 1    Bob   gaming

# %%
from IPython.display import display_html
def display_side_by_side(*args):
    """여러 데이터프레임 비교가 쉽게 옆쪽으로 표시한다"""
    html_str=''
    for df in args:
        html_str += df.to_html() + '&nbsp;'*4
    display_html(html_str.replace('table','table style="display:inline"'), raw=True)

# %%
# 여러 열을 동시에 explode (Pandas 1.3.0 이상)
df = pd.DataFrame({
    'A': [[1, 2], [3]],
    'B': [['a', 'b'], ['c']]
})
df
# Out:
#         A       B
# 0  [1, 2]  [a, b]
# 1     [3]     [c]

# %%
display_side_by_side(df, df.explode(['A']))
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>[1, 2]</td>
#       <td>[a, b]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>[3]</td>
#       <td>[c]</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>[a, b]</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>2</td>
#       <td>[a, b]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3</td>
#       <td>[c]</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;&nbsp;

# %%
display_side_by_side(df, df.explode(['B']))
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>[1, 2]</td>
#       <td>[a, b]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>[3]</td>
#       <td>[c]</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>[1, 2]</td>
#       <td>a</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>[1, 2]</td>
#       <td>b</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>[3]</td>
#       <td>c</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;&nbsp;

# %%
display_side_by_side(df, df.explode(['A', 'B']))
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>[1, 2]</td>
#       <td>[a, b]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>[3]</td>
#       <td>[c]</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>a</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>2</td>
#       <td>b</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3</td>
#       <td>c</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;&nbsp;

# %% [markdown]
# ## 종료
